# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
np.random.uniform(10, 50, 1000)
# Out:
# array([44.46477553, 14.25062894, 26.51910226, 31.27406843, 11.82364925,
#        34.39282201, 11.58209948, 23.41717295, 11.27510327, 43.07848898,
#        39.72066994, 43.59955993, 25.36330704, 31.59657044, 33.89263627,
#        29.72546701, 36.98583889, 26.4963029 , 25.78234931, 25.01223305,
#        21.83246926, 42.04201466, 26.55265336, 42.81612661, 23.51549801,
#        48.65481291, 37.41078592, 24.42792429, 36.63707751, 34.31924756,
#        12.64638886, 20.98584554, 25.26878625, 44.10442923, 48.18881907,
#        40.19204715, 49.58625429, 46.71186036, 40.16276256, 28.63004932,
#        28.17235765, 34.23358093, 36.67971644, 16.27641419, 20.94884381,
#        35.06816274, 43.02397639, 45.94225463, 39.24023165, 34.65762704,
#        38.32953201, 35.68559068, 37.52998043, 14.50844827, 40.91639289,
#        11.23442244, 31.36948779, 13.59747026, 14.11713148, 38.79661408,
#        16.23257385, 14.74095325, 45.81654332, 15.42190051, 40.34040563,
# ...

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def generate_uniform(bottom, ceiling, count):
    """
    Generates an array of uniformly distributed random numbers.
    Parameters:
    - bottom: Lower boundary
    - ceiling: Upper boundary
    - count: Number of values to generate
    """
    return np.random.uniform(bottom, ceiling, count)

# %%
data1 = generate_uniform(10, 15, 100)
data2 = generate_uniform(10, 60, 1000)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

ax1.hist(data1, bins=10)
ax1.set_title("Uniform (10-15, n=100)")
ax1.set_xlabel("Value")
ax1.set_ylabel("Count")

ax2.hist(data2, bins=10)
ax2.set_title("Uniform (10-60, n=1000)")
ax2.set_xlabel("Value")

plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# The two distributions differ primarily in range and density. The first distribution is confined to a small window (5 units), while the second spans 50 units.
# Additionally, because the second set has 1,000 samples, the "rectanglar" shape of the uniform distribution is much more defined and less "jagged" than the smaller sample of 100.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
def generate_normal(mean, std, count):
    """
    Generates an array of normally distributed random numbers.
    Parameters:
    - mean: The center of the distribution (average)
    - std: Standard deviation (spread)
    - count: Number of values to generate
    """
    return np.random.normal(mean, std, count)

# %%
norm1 = generate_normal(10, 1, 1000)

# %%
norm2 = generate_normal(10, 50, 1000)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

ax1.hist(norm1, bins=50)
ax1.set_title("Normal (Mean=10, Std=1)")

ax2.hist(norm2, bins=50)
ax2.set_title("Normal (Mean=10, Std=50)")

plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# While both are centered at 10, the spread is completely different.
# With a standard deviation of 1, almost all data points fall between 7 and 13.
# With a standard deviation of 50, the data points are scattered widely, reaching from roughly -150 to +150.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
vehicles = pd.read_csv('vehicles.csv')
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
variable1 = vehicles['Fuel Barrels/Year']
sns.set_theme(style="whitegrid")

# %%
plt.figure(figsize=(8, 5))
sns.histplot(variable1, bins=30, kde=True, color='teal')

plt.title('Distribution of Fuel Barrels/Year', fontsize=14)
plt.xlabel('Fuel Barrels/Year', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
variable2 = vehicles['CO2 Emission Grams/Mile']

# %%
plt.figure(figsize=(8, 5))
sns.histplot(variable2, bins=30, kde=True, color='darkorange')

plt.title('Distribution of CO2 Emission Grams/Mile', fontsize=14)
plt.xlabel('CO2 Emission Grams/Mile', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
variable3 = vehicles['Combined MPG']

# %%
plt.figure(figsize=(8, 5))
sns.histplot(variable3, bins=30, kde=True, color='forestgreen')

plt.title('Distribution of Combined MPG', fontsize=14)
plt.xlabel('Combined MPG', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# Normality Check: None of these variables follow a perfectly normal distribution.

# %%
# Fuel Barrels/Year: Shows several peaks and a slight skew.

# %%
# CO2 Emissions: Reflects the same pattern as fuel barrels since they are highly correlated.

# %%
# Combined MPG: Shows a right skew because most cars cluster around a common efficiency range, while a few highly efficient vehicles create a long tail to the right.

# %% [markdown]
# None of them are normally ditributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
sns.set_style("whitegrid")

def generate_exponential(mean, size):
    return np.random.exponential(mean, size)

exp_10 = generate_exponential(10, 10)
exp_100 = generate_exponential(10, 100)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), sharey = True)

ax1.hist(exp_10, bins=100)
ax1.set_title("Exponential (n=10)")

ax2.hist(exp_100, bins=100)
ax2.set_title("Exponential (n=100)")

plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
from scipy import stats

mean_time = 10

# %%
prob_less_15 = stats.expon.cdf(15, scale=mean_time)
print(f"Probability of spending < 15 mins: {round(prob_less_15, 3)}")
# Out:
# Probability of spending < 15 mins: 0.777

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
prob_more_15 = 1 - prob_less_15
print(f"Probability of spending > 15 mins: {round(prob_more_15, 3)}")
# Out:
# Probability of spending > 15 mins: 0.223
